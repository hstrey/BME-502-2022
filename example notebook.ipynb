# %%
import Pkg
Pkg.add(["Plots","Distributions"])
# Out:
#     Updating registry at `~/.julia/registries/General`
#    Resolving package versions...
#   No Changes to `~/Documents/programming/BME-502-2022/Project.toml`
#   No Changes to `~/Documents/programming/BME-502-2022/Manifest.toml`

# %%
using Plots
plot([1,2,3,5,7,3])
